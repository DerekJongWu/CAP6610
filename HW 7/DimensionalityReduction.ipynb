# %%
import matplotlib.pyplot as plt
import numpy as np
import math

from sklearn import manifold, datasets

# This import is needed to modify the way figure behaves
from mpl_toolkits.mplot3d import Axes3D
Axes3D

X, color = datasets.samples_generator.make_swiss_roll(n_samples=1500)

X_r, err = manifold.locally_linear_embedding(X, n_neighbors=12,
                                             n_components=2)
embedding = manifold.SpectralEmbedding(n_components = 2,affinity = 'rbf', n_neighbors = 12, gamma = 0.75)
X_l = embedding.fit_transform(X)
print("Done. Reconstruction error: %g" % err)


fig = plt.figure()

ax = fig.add_subplot(211, projection='3d')
ax.scatter(X[:, 0], X[:, 1], X[:, 2], c=color, cmap=plt.cm.Spectral)
plt.title("Original data")

ax = fig.add_subplot(212)
plt.scatter(X_r[:, 0], X_r[:, 1], c=color, cmap=plt.cm.Spectral)
plt.autoscale(enable=True, axis='x', tight=True)
plt.autoscale(enable=True, axis='y', tight=True)
plt.xticks([]), plt.yticks([])
plt.title('Projected data')
plt.show()

plt.scatter(X_l[:,0], X_l[:,1], c = color, cmap=plt.cm.Spectral)
plt.autoscale(enable=True, axis='x', tight=True)
plt.autoscale(enable=True, axis='y', tight=True)
plt.xticks([]), plt.yticks([])
plt.title('Eigenmap data')
plt.show()
# Out:
# Done. Reconstruction error: 8.72783e-08
